# %% [markdown]
# # eval function
# eval() is a built-in Python function used to:
#  Evaluate a string as a Python expression and return the result

# %%
x=eval("3+5")

# %%
x
# Out:
# 8

# %%
x = eval(input("Enter expression: "))
print(x)
# Out:
# 99819.0

# %%
x
# Out:
# 99819.0

# %%
#globals
eval("x+y*100",{"x":10,"y":20})
# Out:
# 2010
