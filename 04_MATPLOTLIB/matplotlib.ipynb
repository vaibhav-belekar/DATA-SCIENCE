# %% [markdown]
# # matplotlib tutorial

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
# simple example 
x=np.arange(0,10)
y=np.arange(11,21)

# %%
#plotting using matplotlib
plt.scatter(x,y,c='red')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter plot')

#plt.savefig('scatter.png')----> if we want to save the plot as an image file
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
## plt plot 
y=x*x
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=10)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line plot')
# Out:
# Text(0.5, 1.0, 'Line plot')

# %%
#creating subplots 
plt.subplot(2,2,1)
plt.plot(x,y,'r--')

plt.subplot(2,2,2)
plt.plot(x,y,'g*-')

plt.subplot(2,2,3)
plt.plot(x,y,'bs-')

plt.subplot(2,2,4)
plt.plot(x,y,'yD-')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# commpute the x and y coordinates for points on a sine curve
x=np.arange(0, 4*np.pi, 0.1)
y=np.sin(x)
plt.title('sine wave form')

#plot the points using matplotlib
plt.plot(x,y)
plt.show()

# %%
#bar plot
x=[2,8,10]
y=[11,16,9]

x2=[3,9,11]
y2=[6,15,7]

plt.bar(x,y)
plt.bar(x2,y2,color='orange')
# Out:
# <BarContainer object of 3 artists>

# %%
# histogram

a=np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a)

plt.title('histogram')
plt.show()

# %% [markdown]
# ## pie chart

# %%
#data to plot 
labels='Python','C++','Ruby','Java'
sizes=[215,130,245,210]
colors=['gold','yellowgreen','lightcoral','lightskyblue']
explode=(0,0.1,0,0) #explode 2nd slice

#plot
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=140)
plt.axis('equal')
plt.show()
