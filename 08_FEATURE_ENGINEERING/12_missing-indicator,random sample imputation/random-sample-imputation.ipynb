# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train.csv',usecols=['Age','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
x=df.drop(columns=['Survived'])
y=df['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train
# Out:
#       Age      Fare
# 30   40.0   27.7208
# 10    4.0   16.7000
# 873  47.0    9.0000
# 182   9.0   31.3875
# 876  20.0    9.8458
# ..    ...       ...
# 534  30.0    8.6625
# 584   NaN    8.7125
# 493  71.0   49.5042
# 527   NaN  221.7792
# 168   NaN   25.9250
#
# [712 rows x 2 columns]

# %%
x_train['Age_imputed']=x_train['Age']
x_test['Age_imputed']=x_test['Age']

# %%
x_test.tail()
# Out:
#       Age     Fare  Age_imputed
# 89   24.0   8.0500         24.0
# 80   22.0   9.0000         22.0
# 846   NaN  69.5500          NaN
# 870  26.0   7.8958         26.0
# 251  29.0  10.4625         29.0

# %%
x_train['Age_imputed'][x_train['Age_imputed'].isnull()]=x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
x_test['Age_imputed'][x_test['Age_imputed'].isnull()] = x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '30     False
# 10     False
# 873    False
# 182    False
# 876    False
#        ...
# 534    False
# 584    False
# 493    False
# 527    False
# 168    False
# Name: Age_imputed, Length: 712, dtype: bool' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1310, in Series.__setitem__(self, key, value)
#    1309 try:
# -> 1310     self._set_with_engine(key, value, warn=warn)
#    1311 except KeyError:
#    1312     # We have a scalar (or for MultiIndex or object-dtype, scalar-like)
#    1313     #  key that is not present in self.index.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1382, in Series._set_with_engine(self, key, value, warn)
#    1381 def _set_with_engine(self, key, value, warn: bool = True) -> None:
# -> 1382     loc = self.index.get_loc(key)
#    1384     # this is equivalent to self._values[key] = value
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3824, in Index.get_loc(self, key)
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
# -> 3824     self._check_indexing_error(key)
#    3825     raise
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6072, in Index._check_indexing_error(self, key)
#    6069 if not is_scalar(key):
#    6070     # if key is not a scalar, directly raise an error (the code below
#    6071     # would convert to numpy arrays and raise later any way) - GH29926
# -> 6072     raise InvalidIndexError(key)
#
# InvalidIndexError: 30     False
# 10     False
# 873    False
# 182    False
# 876    False
#        ...
# 534    False
# 584    False
# 493    False
# 527    False
# 168    False
# Name: Age_imputed, Length: 712, dtype: bool
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 x_train['Age_imputed'][x_train['Age_imputed'].isnull()]=x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
#       2 x_test['Age_imputed'][x_test['Age_imputed'].isnull()] = x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1363, in Series.__setitem__(self, key, value)
#    1353 if (
#    1354     is_list_like(value)
#    1355     and len(value) != len(self)
#    (...)
#    1360     #  _where call below
#    1361     # GH#44265
#    1362     indexer = key.nonzero()[0]
# -> 1363     self._set_values(indexer, value)
#    1364     return
#    1366 # otherwise with listlike other we interpret series[mask] = other
#    1367 #  as series[mask] = other[mask]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1431, in Series._set_values(self, key, value, warn)
#    1428 if isinstance(key, (Index, Series)):
#    1429     key = key._values
# -> 1431 self._mgr = self._mgr.setitem(indexer=key, value=value, warn=warn)
#    1432 self._maybe_update_cacher()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:434, in BaseBlockManager.setitem(self, indexer, value, warn)
#     430     # No need to split if we either set all columns or on a single block
#     431     # manager
#     432     self = self.copy()
# --> 434 return self.apply("setitem", indexer=indexer, value=value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\blocks.py:1469, in Block.setitem(self, indexer, value, using_cow)
#    1466     values = values.T
#    1468 # length checking
# -> 1469 check_setitem_lengths(indexer, value, values)
#    1471 if self.dtype != _dtype_obj:
#    1472     # GH48933: extract_array would convert a pd.Series value to np.ndarray
#    1473     value = extract_array(value, extract_numpy=True)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexers\utils.py:166, in check_setitem_lengths(indexer, value, values)
#     160         indexer = np.array(indexer)
#     161     if not (
#     162         isinstance(indexer, np.ndarray)
#     163         and indexer.dtype == np.bool_
#     164         and indexer.sum() == len(value)
#     165     ):
# --> 166         raise ValueError(
#     167             "cannot set using a list-like indexer "
#     168             "with a different length than the value"
#     169         )
#     170 if not len(indexer):
#     171     no_op = True
#
# ValueError: cannot set using a list-like indexer with a different length than the value

# %%
x_test['Age_imputed'][x_test['Age_imputed'].isnull()] = x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_26792\3885208445.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test['Age_imputed'][x_test['Age_imputed'].isnull()] = x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '707    False
# 37     False
# 615    False
# 169    False
# 68     False
#        ...
# 89     False
# 80     False
# 846    False
# 870    False
# 251    False
# Name: Age_imputed, Length: 179, dtype: bool' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1310, in Series.__setitem__(self, key, value)
#    1309 try:
# -> 1310     self._set_with_engine(key, value, warn=warn)
#    1311 except KeyError:
#    1312     # We have a scalar (or for MultiIndex or object-dtype, scalar-like)
#    1313     #  key that is not present in self.index.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1382, in Series._set_with_engine(self, key, value, warn)
#    1381 def _set_with_engine(self, key, value, warn: bool = True) -> None:
# -> 1382     loc = self.index.get_loc(key)
#    1384     # this is equivalent to self._values[key] = value
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3824, in Index.get_loc(self, key)
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
# -> 3824     self._check_indexing_error(key)
#    3825     raise
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6072, in Index._check_indexing_error(self, key)
#    6069 if not is_scalar(key):
#    6070     # if key is not a scalar, directly raise an error (the code below
#    6071     # would convert to numpy arrays and raise later any way) - GH29926
# -> 6072     raise InvalidIndexError(key)
#
# InvalidIndexError: 707    False
# 37     False
# 615    False
# 169    False
# 68     False
#        ...
# 89     False
# 80     False
# 846    False
# 870    False
# 251    False
# Name: Age_imputed, Length: 179, dtype: bool
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 x_test['Age_imputed'][x_test['Age_imputed'].isnull()] = x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1363, in Series.__setitem__(self, key, value)
#    1353 if (
#    1354     is_list_like(value)
#    1355     and len(value) != len(self)
#    (...)
#    1360     #  _where call below
#    1361     # GH#44265
#    1362     indexer = key.nonzero()[0]
# -> 1363     self._set_values(indexer, value)
#    1364     return
#    1366 # otherwise with listlike other we interpret series[mask] = other
#    1367 #  as series[mask] = other[mask]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1431, in Series._set_values(self, key, value, warn)
#    1428 if isinstance(key, (Index, Series)):
#    1429     key = key._values
# -> 1431 self._mgr = self._mgr.setitem(indexer=key, value=value, warn=warn)
#    1432 self._maybe_update_cacher()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:434, in BaseBlockManager.setitem(self, indexer, value, warn)
#     430     # No need to split if we either set all columns or on a single block
#     431     # manager
#     432     self = self.copy()
# --> 434 return self.apply("setitem", indexer=indexer, value=value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\blocks.py:1469, in Block.setitem(self, indexer, value, using_cow)
#    1466     values = values.T
#    1468 # length checking
# -> 1469 check_setitem_lengths(indexer, value, values)
#    1471 if self.dtype != _dtype_obj:
#    1472     # GH48933: extract_array would convert a pd.Series value to np.ndarray
#    1473     value = extract_array(value, extract_numpy=True)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexers\utils.py:166, in check_setitem_lengths(indexer, value, values)
#     160         indexer = np.array(indexer)
#     161     if not (
#     162         isinstance(indexer, np.ndarray)
#     163         and indexer.dtype == np.bool_
#     164         and indexer.sum() == len(value)
#     165     ):
# --> 166         raise ValueError(
#     167             "cannot set using a list-like indexer "
#     168             "with a different length than the value"
#     169         )
#     170 if not len(indexer):
#     171     no_op = True
#
# ValueError: cannot set using a list-like indexer with a different length than the value
